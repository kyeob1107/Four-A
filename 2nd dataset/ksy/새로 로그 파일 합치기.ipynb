# %% [markdown]
# # 이전

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# col 생략 없이 출력
pd.set_option('display.max_columns', None)

log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")
log_sort_df = log_df.sort_values(by=['CustomerID', 'Timestamp'])
log_sort_df = log_sort_df.reset_index(drop=True)
ad_click_df = log_sort_df[log_sort_df['ActionType']=='ad_click']
ad_click_df.loc[:, 'GoodsCode'] = ad_click_df['GoodsCode'].astype(pd.Int16Dtype())

# 결과를 저장할 빈 데이터프레임 생성
result_df = pd.DataFrame()

# `CustomerID`별로 그룹화하고 각 그룹에 대해 merge_asof 실행
for customer_id, group in tqdm(log_sort_df.groupby('CustomerID')):
    temp_ad_click = ad_click_df[ad_click_df['CustomerID'] == customer_id]
    merged_group = pd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
    result_df = pd.concat([result_df, merged_group])

# %%
import dask.dataframe as dd
import pandas as pd
from tqdm.auto import tqdm

# 예시 데이터 로드 및 전처리 (Pandas)
log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")

# %%
len(log_df)
# Out:
# 3096931

# %%
log_df['CustomerID'].nunique()
# Out:
# 228675

# %%
import dask.dataframe as dd
import pandas as pd
from tqdm.auto import tqdm

# 예시 데이터 로드 및 전처리 (Pandas)
log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")
log_sort_df = log_df.sort_values(by=['CustomerID', 'Timestamp']).reset_index(drop=True)
ad_click_df = log_sort_df[log_sort_df['ActionType'] == 'ad_click']
ad_click_df.loc[:, 'GoodsCode'] = ad_click_df['GoodsCode'].astype(pd.Int16Dtype())

# Pandas DataFrame을 Dask DataFrame으로 변환
log_sort_ddf = dd.from_pandas(log_sort_df, npartitions=10)
ad_click_ddf = dd.from_pandas(ad_click_df, npartitions=10)

# 각 CustomerID별로 처리 후 결과를 리스트에 저장
results = []
# grouped = list(log_sort_ddf.groupby('CustomerID'))  # Dask groupby 결과를 리스트로 변환
for customer_id, group in log_sort_ddf.groupby('CustomerID'): # tqdm(grouped):  # tqdm으로 진행 상황 표시 
    temp_ad_click = ad_click_ddf[ad_click_ddf['CustomerID'] == customer_id]
    merged_group = dd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
    results.append(merged_group)

# 모든 결과를 합침
final_result_ddf = dd.concat(results)

# 최종 결과를 확인 (Dask DataFrame을 Pandas DataFrame으로 변환)
final_result_df = final_result_ddf.compute()
print(final_result_df)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 18
#      16 results = []
#      17 # grouped = list(log_sort_ddf.groupby('CustomerID'))  # Dask groupby 결과를 리스트로 변환
# ---> 18 for customer_id, group in log_sort_ddf.groupby('CustomerID'): # tqdm(grouped):  # tqdm으로 진행 상황 표시
#      19     temp_ad_click = ad_click_ddf[ad_click_ddf['CustomerID'] == customer_id]
#      20     merged_group = dd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\dataframe\groupby.py:1493, in _GroupBy.__iter__(self)
#    1492 def __iter__(self):
# -> 1493     raise NotImplementedError(
#    1494         "Iteration of DataFrameGroupBy objects requires computing the groups which "
#    1495         "may be slow. You probably want to use 'apply' to execute a function for "
#    1496         "all the columns. To access individual groups, use 'get_group'. To list "
#    1497         "all the group names, use 'df[<group column>].unique().compute()'."
#    1498     )
#
# NotImplementedError: Iteration of DataFrameGroupBy objects requires computing the groups which may be slow. You probably want to use 'apply' to execute a function for all the columns. To access individual groups, use 'get_group'. To list all the group names, use 'df[<group column>].unique().compute()'.

# %%
import dask.dataframe as dd
import pandas as pd
from tqdm.auto import tqdm

# 예시 데이터 로드 및 전처리 (Pandas)
log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")
log_sort_df = log_df.sort_values(by=['CustomerID', 'Timestamp']).reset_index(drop=True)
ad_click_df = log_sort_df[log_sort_df['ActionType'] == 'ad_click']
ad_click_df.loc[:, 'GoodsCode'] = ad_click_df['GoodsCode'].astype(pd.Int16Dtype())

# Pandas DataFrame을 Dask DataFrame으로 변환
log_sort_ddf = dd.from_pandas(log_sort_df, npartitions=10)
ad_click_ddf = dd.from_pandas(ad_click_df, npartitions=10)

# CustomerID 기준으로 데이터 파티션
log_sort_ddf = log_sort_ddf.shuffle('CustomerID')
ad_click_ddf = ad_click_ddf.shuffle('CustomerID')

# apply를 사용하여 각 CustomerID별로 처리
def process_group(group, ad_click_ddf):
    customer_id = group['CustomerID'].iloc[0]
    temp_ad_click = ad_click_ddf[ad_click_ddf['CustomerID'] == customer_id]
    return dd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))

results = log_sort_ddf.groupby('CustomerID').apply(process_group, ad_click_ddf=ad_click_ddf, meta=log_sort_ddf).compute()

display(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 25
#      22     temp_ad_click = ad_click_ddf[ad_click_ddf['CustomerID'] == customer_id]
#      23     return dd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
# ---> 25 results = log_sort_ddf.groupby('CustomerID').apply(process_group, ad_click_ddf=ad_click_ddf, meta=log_sort_ddf).compute()
#      27 display(results)
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\optimization.py:990, in SubgraphCallable.__call__(self, *args)
#     988 if not len(args) == len(self.inkeys):
#     989     raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 990 return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\core.py:149, in get(dsk, out, cache)
#     147 for key in toposort(dsk):
#     148     task = dsk[key]
# --> 149     result = _execute_task(task, cache)
#     150     cache[key] = result
#     151 result = _execute_task(out, cache)
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\utils.py:73, in apply(func, args, kwargs)
#      42 """Apply a function given its positional and keyword arguments.
#      43
#      44 Equivalent to ``func(*args, **kwargs)``
#    (...)
#      70 >>> dsk = {'task-name': task}  # adds the task to a low level Dask task graph
#      71 """
#      72 if kwargs:
# ---> 73     return func(*args, **kwargs)
#      74 else:
#      75     return func(*args)
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\dataframe\core.py:7023, in apply_and_enforce(*args, **kwargs)
#    7021 func = kwargs.pop("_func")
#    7022 meta = kwargs.pop("_meta")
# -> 7023 df = func(*args, **kwargs)
#    7024 if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    7025     if not len(df):
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\dataframe\groupby.py:229, in _groupby_slice_apply(df, grouper, key, func, group_keys, dropna, observed, *args, **kwargs)
#     227 if key:
#     228     g = g[key]
# --> 229 return g.apply(func, *args, **kwargs)
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1351 with option_context("mode.chained_assignment", None):
#    1352     try:
# -> 1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
#    1363         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py:1341, in GroupBy.apply.<locals>.f(g)
#    1338 @wraps(func)
#    1339 def f(g):
#    1340     with np.errstate(all="ignore"):
# -> 1341         return func(g, *args, **kwargs)
#
# Cell In[1], line 23, in process_group(group, ad_click_ddf)
#      21 customer_id = group['CustomerID'].iloc[0]
#      22 temp_ad_click = ad_click_ddf[ad_click_ddf['CustomerID'] == customer_id]
# ---> 23 return dd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\dask\dataframe\multi.py:953, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     951 # if is_dataframe_like(left) and is_dataframe_like(right):
#     952 if isinstance(left, pd.DataFrame) and isinstance(right, pd.DataFrame):
# --> 953     return pd.merge_asof(left, right, **kwargs)
#     955 if on is not None:
#     956     if left_on is not None or right_on is not None:
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py:633, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     377 """
#     378 Perform a merge by key distance.
#     379
#    (...)
#     614 4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     615 """
#     616 op = _AsOfMerge(
#     617     left,
#     618     right,
#    (...)
#     631     direction=direction,
#     632 )
# --> 633 return op.get_result()
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py:1816, in _OrderedMerge.get_result(self, copy)
#    1815 def get_result(self, copy: bool | None = True) -> DataFrame:
# -> 1816     join_index, left_indexer, right_indexer = self._get_join_info()
#    1818     llabels, rlabels = _items_overlap_with_suffix(
#    1819         self.left._info_axis, self.right._info_axis, self.suffixes
#    1820     )
#    1822     left_join_indexer: np.ndarray | None
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py:1065, in _MergeOperation._get_join_info(self)
#    1061     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1062         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1063     )
#    1064 else:
# -> 1065     (left_indexer, right_indexer) = self._get_join_indexers()
#    1067     if self.right_index:
#    1068         if len(self.left) > 0:
#
# File c:\Users\kssg1\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py:2110, in _AsOfMerge._get_join_indexers(self)
#    2108     if isna(left_values).any():
#    2109         raise ValueError(f"Merge keys contain null values on {side} side")
# -> 2110     raise ValueError(f"{side} keys must be sorted")
#    2112 if not Index(right_values).is_monotonic_increasing:
#    2113     side = "right"
#
# ValueError: left keys must be sorted

# %% [markdown]
# # 다시 시간 단축

# %%
import pandas as pd
from tqdm import tqdm

log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")
log_sort_df = log_df.sort_values(by=['CustomerID', 'Timestamp'])
log_sort_df = log_sort_df.reset_index(drop=True)

# %%
log_sort_partitioin_dict = {}
for num in range(10):
    log_sort_partitioin_dict[f'df_{num}'] = log_sort_df[log_sort_df['CustomerID']%10 == num]

# %%
for num, df in log_sort_partitioin_dict.items():
    print(f"{num}, {len(df)}")
# Out:
# df_0, 310840
# df_1, 311817
# df_2, 308119
# df_3, 312746
# df_4, 310147
# df_5, 309864
# df_6, 308830
# df_7, 306167
# df_8, 310450
# df_9, 307951

# %%
ad_click_partitioin_dict = {}
for df_name, _ in log_sort_partitioin_dict.items():
    ad_click_partitioin_dict[df_name] = log_sort_partitioin_dict[df_name][log_sort_partitioin_dict[df_name]['ActionType']=='ad_click']
    ad_click_partitioin_dict[df_name] = ad_click_partitioin_dict[df_name].astype({'GoodsCode':'Int16'})

# %%
# 결과를 저장할 빈 데이터프레임 생성
result_dict = {}
for df_name, log_df in tqdm(log_sort_partitioin_dict.items()):
    result_dict[df_name] = pd.DataFrame()
    print(df_name)
    # `CustomerID`별로 그룹화하고 각 그룹에 대해 merge_asof 실행
    for customer_id, group in tqdm(log_df.groupby('CustomerID')):
        temp_ad_click = ad_click_partitioin_dict[df_name][ad_click_partitioin_dict[df_name]['CustomerID'] == customer_id]
        merged_group = pd.merge_asof(group, temp_ad_click, on='Timestamp', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))
        result_dict[df_name] = pd.concat([result_dict[df_name], merged_group])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# df_0
# 100%|██████████| 22950/22950 [02:25<00:00, 157.66it/s]
#  10%|█         | 1/10 [02:25<21:52, 145.79s/it]
# df_1
# 100%|██████████| 22964/22964 [02:25<00:00, 158.01it/s]
#  20%|██        | 2/10 [04:51<19:24, 145.59s/it]
# df_2
# 100%|██████████| 22786/22786 [02:21<00:00, 160.70it/s]
#  30%|███       | 3/10 [07:13<16:48, 144.08s/it]
# df_3
# 100%|██████████| 22935/22935 [02:26<00:00, 156.17it/s]
#  40%|████      | 4/10 [09:40<14:31, 145.22s/it]
# df_4
# 100%|██████████| 22894/22894 [02:26<00:00, 156.46it/s]
#  50%|█████     | 5/10 [12:06<12:08, 145.65s/it]
# df_5
# 100%|██████████| 22875/22875 [02:25<00:00, 157.61it/s]
#  60%|██████    | 6/10 [14:32<09:42, 145.74s/it]
# df_6
# 100%|██████████| 22922/22922 [02:26<00:00, 156.44it/s]
#  70%|███████   | 7/10 [16:59<07:18, 146.03s/it]
# df_7
# 100%|██████████| 22640/22640 [02:24<00:00, 156.48it/s]
#  80%|████████  | 8/10 [19:24<04:51, 145.63s/it]
# df_8
# 100%|██████████| 22886/22886 [02:26<00:00, 155.78it/s]
#  90%|█████████ | 9/10 [21:51<02:26, 146.07s/it]
# df_9
# 100%|██████████| 22823/22823 [02:25<00:00, 156.59it/s]
# 100%|██████████| 10/10 [24:18<00:00, 145.81s/it]

# %%
for df in result_dict.values():
    # print(df)
    display(df.head(3))
# Out:
#    CustomerID ActionType  GoodsCode   Price AdID  CPC  \
# 0          30       view       1163  100790  NaN  NaN
# 1          30       view       1163  100790  NaN  NaN
# 2          30     basket       1163  100790  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-02-12 18:58:09.707955            NaN           NaN          <NA>
# 1 2022-02-24 11:56:13.707955            NaN           NaN          <NA>
# 2 2022-02-26 19:07:45.707955            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0          81       view       1334  10890  NaN  NaN
# 1          81       view       1334  10890  NaN  NaN
# 2          81   purchase       1334  10890  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-05-02 17:18:45.297618            NaN           NaN          <NA>
# 1 2022-05-10 03:52:06.297618            NaN           NaN          <NA>
# 2 2022-06-06 17:14:05.297618            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0          32       view       1434  18720  NaN  NaN
# 1          32     basket       1434  18720  NaN  NaN
# 2          32   purchase       1201  13550  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-02-10 00:45:33.376860            NaN           NaN          <NA>
# 1 2022-02-11 14:00:06.376860            NaN           NaN          <NA>
# 2 2022-02-26 16:27:44.376860            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price       AdID     CPC  \
# 0          13       view       1367  42850        NaN     NaN
# 1          13   purchase       1367  42850        NaN     NaN
# 2          13   ad_click       1090  21100  ad_google  158.68
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-02-25 16:00:46.855443            NaN           NaN          <NA>
# 1 2022-02-27 08:38:57.855443            NaN           NaN          <NA>
# 2 2022-03-11 18:14:48.855443           13.0      ad_click          1090
#
#    Price_ad    AdID_ad  CPC_ad
# 0       NaN        NaN     NaN
# 1       NaN        NaN     NaN
# 2   21100.0  ad_google  158.68
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0           4       view       1492  15020  NaN  NaN
# 1           4       view       1492  15020  NaN  NaN
# 0          14       view       1280   9270  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-07-04 15:11:42.511967            NaN           NaN          <NA>
# 1 2022-07-24 14:44:40.511967            NaN           NaN          <NA>
# 0 2022-02-14 07:41:09.548570            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 0       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0          55       view       1370   8190  NaN  NaN
# 1          55       view       1370   8190  NaN  NaN
# 2          55       view       1035  21440  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-02-10 16:56:23.008345            NaN           NaN          <NA>
# 1 2022-02-12 03:43:16.008345            NaN           NaN          <NA>
# 2 2022-03-05 11:50:13.008345            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0           6       view       1415  12980  NaN  NaN
# 1           6   purchase       1437  35290  NaN  NaN
# 2           6       view       1217  16220  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-04-22 15:49:44.166991            NaN           NaN          <NA>
# 1 2022-04-26 21:46:00.166991            NaN           NaN          <NA>
# 2 2022-05-03 14:26:12.811783            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode   Price AdID  CPC  \
# 0          17   purchase       1445   19950  NaN  NaN
# 1          17       view       1086  144050  NaN  NaN
# 2          17     basket       1094  100040  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-03-13 15:47:28.525882            NaN           NaN          <NA>
# 1 2022-03-17 22:53:09.525882            NaN           NaN          <NA>
# 2 2022-03-20 15:30:33.525882            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0           8     basket       1372  24930  NaN  NaN
# 1           8       view       1372  24930  NaN  NaN
# 2           8   purchase       1372  24930  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-02-24 01:10:10.156038            NaN           NaN          <NA>
# 1 2022-03-08 02:02:34.156038            NaN           NaN          <NA>
# 2 2022-03-08 03:17:01.156038            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
#    CustomerID ActionType  GoodsCode   Price AdID  CPC  \
# 0          89   purchase       1087  136830  NaN  NaN
# 1          89       view       1087  136830  NaN  NaN
# 2          89       view       1487   19730  NaN  NaN
#
#                    Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0 2022-03-13 14:17:01.534376            NaN           NaN          <NA>
# 1 2022-03-14 11:27:23.534376            NaN           NaN          <NA>
# 2 2022-03-30 22:26:08.534376            NaN           NaN          <NA>
#
#    Price_ad AdID_ad  CPC_ad
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN

# %%
result_for_concat_list = []
for df in result_dict.values():
    result_for_concat_list.append(df)

# %%
finally_result = pd.concat(result_for_concat_list).sort_values(by=['CustomerID', 'Timestamp'])

# %%
finally_result
# Out:
#     CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 0            4       view       1492  15020  NaN  NaN
# 1            4       view       1492  15020  NaN  NaN
# 0            6       view       1415  12980  NaN  NaN
# 1            6   purchase       1437  35290  NaN  NaN
# 2            6       view       1217  16220  NaN  NaN
# ..         ...        ...        ...    ...  ...  ...
# 28      899999       view       1059  21230  NaN  NaN
# 29      899999     basket       1059  21230  NaN  NaN
# 30      899999       view       1059  21230  NaN  NaN
# 31      899999   purchase       1034  12910  NaN  NaN
# 32      899999       view       1168  91680  NaN  NaN
#
#                     Timestamp  CustomerID_ad ActionType_ad  GoodsCode_ad  \
# 0  2022-07-04 15:11:42.511967            NaN           NaN          <NA>
# 1  2022-07-24 14:44:40.511967            NaN           NaN          <NA>
# 0  2022-04-22 15:49:44.166991            NaN           NaN          <NA>
# 1  2022-04-26 21:46:00.166991            NaN           NaN          <NA>
# 2  2022-05-03 14:26:12.811783            NaN           NaN          <NA>
# ..                        ...            ...           ...           ...
# 28 2022-05-22 12:51:15.722389            NaN           NaN          <NA>
# 29 2022-05-23 01:28:11.722389            NaN           NaN          <NA>
# 30 2022-05-24 04:40:26.722389            NaN           NaN          <NA>
# 31 2022-06-20 03:40:43.722389            NaN           NaN          <NA>
# 32 2022-06-23 08:16:44.304854            NaN           NaN          <NA>
#
#     Price_ad AdID_ad  CPC_ad
# 0        NaN     NaN     NaN
# 1        NaN     NaN     NaN
# 0        NaN     NaN     NaN
# 1        NaN     NaN     NaN
# 2        NaN     NaN     NaN
# ..       ...     ...     ...
# 28       NaN     NaN     NaN
# 29       NaN     NaN     NaN
# 30       NaN     NaN     NaN
# 31       NaN     NaN     NaN
# 32       NaN     NaN     NaN
#
# [3096931 rows x 13 columns]

# %%
# finally_result.to_parquet("result_all_df.parquet")

# %%
import pandas as pd

log_eval_all_df = pd.read_parquet("result_all_df.parquet")

# %%
import numpy as np

# null값 있어서 Int16으로 했는데 이 타입 있으면 np.select typeerror나서 null->-1로 하고 타입변환
log_eval_all_df['GoodsCode_ad'] = log_eval_all_df['GoodsCode_ad'].fillna(-1)
log_eval_all_df['GoodsCode_ad'] = log_eval_all_df['GoodsCode_ad'].astype('int16')

# 조건 리스트
conditions = [
    (log_eval_all_df['GoodsCode_ad']==-1) & (log_eval_all_df['ActionType']=='view'), # not_ad_view
    (log_eval_all_df['GoodsCode_ad']==-1) & (log_eval_all_df['ActionType']=='basket'), # not_ad_basket
    (log_eval_all_df['GoodsCode_ad']==-1) & (log_eval_all_df['ActionType']=='purchase'), # not_ad_purchase
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='ad_click')), # ad_click
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='purchase')
     & (log_eval_all_df['GoodsCode']==log_eval_all_df['GoodsCode_ad'])), # ad_purchase
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='purchase') 
     & (log_eval_all_df['GoodsCode']!=log_eval_all_df['GoodsCode_ad'])), # ad_purchase_other
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='view') 
     & (log_eval_all_df['GoodsCode']==log_eval_all_df['GoodsCode_ad'])), # ad_view
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='basket') 
     & (log_eval_all_df['GoodsCode']==log_eval_all_df['GoodsCode_ad'])), # ad_basket
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='view') 
     & (log_eval_all_df['GoodsCode']!=log_eval_all_df['GoodsCode_ad'])), # ad_view_other
    ((log_eval_all_df['GoodsCode_ad']!=-1) & (log_eval_all_df['ActionType']=='basket') 
     & (log_eval_all_df['GoodsCode']!=log_eval_all_df['GoodsCode_ad'])), # ad_basket_other
    
]

# 조건에 따른 값 리스트
choices = ['not_ad_view', 'not_ad_basket', 'not_ad_purchase', 
           'ad_click', 'ad_purchase', 'ad_purchase_other', 
           'ad_view', 'ad_basket', 'ad_view_other', 'ad_basket_other']

# numpy.select를 사용하여 새 컬럼에 조건부 값 할당
log_eval_all_df = log_eval_all_df.assign(eval_type=np.select(conditions, choices, default='Fail'))

# 혹시 몰라 결과 공유하기 위해서 저장
# log_eval_all_df.to_parquet("log_eval_all_df.parquet")

# %%
import pandas as pd

log_eval_all_df = pd.read_parquet("log_eval_all_df.parquet")
log_eval_all_df = log_eval_all_df.drop(['CustomerID_ad', 'ActionType_ad'], axis=1)

# %%
log_eval_all_df[log_eval_all_df['GoodsCode_ad']!=-1]
# Out:
#     CustomerID ActionType  GoodsCode   Price       AdID     CPC  \
# 5            6   ad_click       1437   35290  ad_google  182.31
# 6            6       view       1437   35290        NaN     NaN
# 2           13   ad_click       1090   21100  ad_google  158.68
# 3           13       view       1203   85290        NaN     NaN
# 4           14   ad_click       1000   12580  ad_google  104.04
# ..         ...        ...        ...     ...        ...     ...
# 16      899993       view       1045  120410        NaN     NaN
# 18      899999   ad_click       1059   21230    ad_meta   71.35
# 19      899999       view       1271   92940        NaN     NaN
# 25      899999   ad_click       1059   21230  ad_google   94.14
# 26      899999     basket       1059   21230        NaN     NaN
#
#                     Timestamp  GoodsCode_ad  Price_ad    AdID_ad  CPC_ad  \
# 5  2022-05-07 21:00:59.166991          1437   35290.0  ad_google  182.31
# 6  2022-05-12 10:25:41.166991          1437   35290.0  ad_google  182.31
# 2  2022-03-11 18:14:48.855443          1090   21100.0  ad_google  158.68
# 3  2022-03-17 14:31:19.855443          1090   21100.0  ad_google  158.68
# 4  2022-03-07 10:33:24.548570          1000   12580.0  ad_google  104.04
# ..                        ...           ...       ...        ...     ...
# 16 2022-05-11 03:04:39.372529          1019   16840.0    ad_meta   88.20
# 18 2022-04-06 21:09:47.722389          1059   21230.0    ad_meta   71.35
# 19 2022-04-10 18:07:56.722389          1059   21230.0    ad_meta   71.35
# 25 2022-05-06 00:08:17.722389          1059   21230.0  ad_google   94.14
# 26 2022-05-11 10:09:46.722389          1059   21230.0  ad_google   94.14
#
#         eval_type
# 5        ad_click
# 6         ad_view
# 2        ad_click
# 3   ad_view_other
# 4        ad_click
# ..            ...
# 16  ad_view_other
# 18       ad_click
# 19  ad_view_other
# 25       ad_click
# 26      ad_basket
#
# [357656 rows x 12 columns]

# %% [markdown]
# # by중복있으면 안되는 것 아니였나? 다른 곳에선 또 되는 것 같아서 다시 확인(확인 결과 중복이 문제가 아니라 on의 컬럼이 가장 첫 기준으로 정렬되어있어야 하는 듯)

# %%
import pandas as pd
from tqdm import tqdm

log_df = pd.read_parquet("./dataset/real_log_for_spartan_optimized.parquet")
log_sort_df = log_df.sort_values(by=['CustomerID', 'Timestamp'])
log_sort_df = log_sort_df.reset_index(drop=True)

# %%
merge_log_sort_df = log_sort_df.sort_values(by='Timestamp')

# %%
merge_ad_click = merge_log_sort_df[merge_log_sort_df['ActionType']=='ad_click'].astype({'GoodsCode':'Int16'})

# %%
merge_simple = pd.merge_asof(merge_log_sort_df, merge_ad_click, on='Timestamp', by='CustomerID', tolerance=pd.Timedelta(days=7), direction='backward', suffixes=('', '_ad'))

# %%
merge_simple = merge_simple.sort_values(by=['CustomerID', 'Timestamp'])
merge_simple
# Out:
#          CustomerID ActionType  GoodsCode  Price AdID  CPC  \
# 3081601           4       view       1492  15020  NaN  NaN
# 3090577           4       view       1492  15020  NaN  NaN
# 1627572           6       view       1415  12980  NaN  NaN
# 1773519           6   purchase       1437  35290  NaN  NaN
# 1998478           6       view       1217  16220  NaN  NaN
# ...             ...        ...        ...    ...  ...  ...
# 2552733      899999       view       1059  21230  NaN  NaN
# 2565501      899999     basket       1059  21230  NaN  NaN
# 2592523      899999       view       1059  21230  NaN  NaN
# 3016105      899999   purchase       1034  12910  NaN  NaN
# 3038579      899999       view       1168  91680  NaN  NaN
#
#                          Timestamp ActionType_ad  GoodsCode_ad  Price_ad  \
# 3081601 2022-07-04 15:11:42.511967           NaN           NaN       NaN
# 3090577 2022-07-24 14:44:40.511967           NaN           NaN       NaN
# 1627572 2022-04-22 15:49:44.166991           NaN           NaN       NaN
# 1773519 2022-04-26 21:46:00.166991           NaN           NaN       NaN
# 1998478 2022-05-03 14:26:12.811783           NaN           NaN       NaN
# ...                            ...           ...           ...       ...
# 2552733 2022-05-22 12:51:15.722389           NaN           NaN       NaN
# 2565501 2022-05-23 01:28:11.722389           NaN           NaN       NaN
# 2592523 2022-05-24 04:40:26.722389           NaN           NaN       NaN
# 3016105 2022-06-20 03:40:43.722389           NaN           NaN       NaN
# 3038579 2022-06-23 08:16:44.304854           NaN           NaN       NaN
#
#         AdID_ad  CPC_ad
# 3081601     NaN     NaN
# 3090577     NaN     NaN
# 1627572     NaN     NaN
# 1773519     NaN     NaN
# 1998478     NaN     NaN
# ...         ...     ...
# 2552733     NaN     NaN
# 2565501     NaN     NaN
# 2592523     NaN     NaN
# 3016105     NaN     NaN
# 3038579     NaN     NaN
#
# [3096931 rows x 12 columns]
