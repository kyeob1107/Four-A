# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
customer = pd.read_csv('/Users/hj/Documents/무제/최종프로젝트/data/Customer_info.csv')
customer
# Out:
#            고객ID 성별        고객지역  가입기간
# 0     USER_1358  남     Chicago    12
# 1     USER_0190  남  California    43
# 2     USER_0066  남     Chicago    33
# 3     USER_0345  여  California    30
# 4     USER_0683  남  California    49
# ...         ... ..         ...   ...
# 1463  USER_0513  여    New York    41
# 1464  USER_0167  여     Chicago    48
# 1465  USER_0845  남  New Jersey    19
# 1466  USER_0504  여    New York    45
# 1467  USER_0562  여  California     7
#
# [1468 rows x 4 columns]

# %%
discount = pd.read_csv('/Users/hj/Documents/무제/최종프로젝트/data/Discount_info.csv')
discount
# Out:
#        월                제품카테고리    쿠폰코드  할인율
# 0    Jan               Apparel  SALE10   10
# 1    Feb               Apparel  SALE20   20
# 2    Mar               Apparel  SALE30   30
# 3    Jan              Nest-USA  ELEC10   10
# 4    Feb              Nest-USA  ELEC20   20
# ..   ...                   ...     ...  ...
# 199  Nov  Notebooks & Journals    NJ20   20
# 200  Dec  Notebooks & Journals    NJ30   30
# 201  Oct               Android   AND10   10
# 202  Nov               Android   AND20   20
# 203  Dec               Android   AND30   30
#
# [204 rows x 4 columns]

# %%
marketing = pd.read_csv('/Users/hj/Documents/무제/최종프로젝트/data/Marketing_info.csv')
marketing
# Out:
#              날짜  오프라인비용    온라인비용
# 0    2019-01-01    4500  2424.50
# 1    2019-01-02    4500  3480.36
# 2    2019-01-03    4500  1576.38
# 3    2019-01-04    4500  2928.55
# 4    2019-01-05    4500  4055.30
# ..          ...     ...      ...
# 360  2019-12-27    4000  3396.87
# 361  2019-12-28    4000  3246.84
# 362  2019-12-29    4000  2546.58
# 363  2019-12-30    4000   674.31
# 364  2019-12-31    4000  2058.75
#
# [365 rows x 3 columns]

# %%
onlinesales = pd.read_csv('/Users/hj/Documents/무제/최종프로젝트/data/Onlinesales_info.csv')
onlinesales
# Out:
#             고객ID               거래ID        거래날짜          제품ID    제품카테고리  수량  \
# 0      USER_1358   Transaction_0000  2019-01-01  Product_0981  Nest-USA   1
# 1      USER_1358   Transaction_0001  2019-01-01  Product_0981  Nest-USA   1
# 2      USER_1358   Transaction_0002  2019-01-01  Product_0904    Office   1
# 3      USER_1358   Transaction_0003  2019-01-01  Product_0203   Apparel   5
# 4      USER_1358   Transaction_0003  2019-01-01  Product_0848      Bags   1
# ...          ...                ...         ...           ...       ...  ..
# 52919  USER_0504  Transaction_25056  2019-12-31  Product_0976  Nest-USA   1
# 52920  USER_0504  Transaction_25057  2019-12-31  Product_0413   Apparel   1
# 52921  USER_0504  Transaction_25058  2019-12-31  Product_0989  Nest-USA   1
# 52922  USER_0562  Transaction_25059  2019-12-31  Product_0985  Nest-USA   5
# 52923  USER_0562  Transaction_25060  2019-12-31  Product_0984  Nest-USA   4
#
#          평균금액    배송료      쿠폰상태
# ...

# %%
tax = pd.read_csv('/Users/hj/Documents/무제/최종프로젝트/data/Tax_info.csv')
tax
# Out:
#                   제품카테고리   GST
# 0               Nest-USA  0.10
# 1                 Office  0.10
# 2                Apparel  0.18
# 3                   Bags  0.18
# 4              Drinkware  0.18
# 5              Lifestyle  0.18
# 6   Notebooks & Journals  0.05
# 7               Headgear  0.05
# 8                   Waze  0.18
# 9                    Fun  0.18
# 10           Nest-Canada  0.10
# 11             Backpacks  0.10
# 12                Google  0.10
# 13               Bottles  0.05
# 14            Gift Cards  0.05
# 15             More Bags  0.18
# 16            Housewares  0.12
# 17               Android  0.10
# 18           Accessories  0.10
# 19                  Nest  0.05

# %%
total_sales = pd.merge(onlinesales, customer, on = '고객ID', how='left')
total_sales.head(20)
# Out:
#          고객ID              거래ID        거래날짜          제품ID     제품카테고리  수량  \
# 0   USER_1358  Transaction_0000  2019-01-01  Product_0981   Nest-USA   1
# 1   USER_1358  Transaction_0001  2019-01-01  Product_0981   Nest-USA   1
# 2   USER_1358  Transaction_0002  2019-01-01  Product_0904     Office   1
# 3   USER_1358  Transaction_0003  2019-01-01  Product_0203    Apparel   5
# 4   USER_1358  Transaction_0003  2019-01-01  Product_0848       Bags   1
# 5   USER_1358  Transaction_0003  2019-01-01  Product_0854       Bags  15
# 6   USER_1358  Transaction_0003  2019-01-01  Product_0880  Drinkware  15
# 7   USER_1358  Transaction_0003  2019-01-01  Product_0885  Drinkware  15
# 8   USER_1358  Transaction_0003  2019-01-01  Product_0898  Drinkware   5
# 9   USER_0190  Transaction_0003  2019-01-01  Product_0914     Office  52
# 10  USER_0190  Transaction_0003  2019-01-01  Product_0966     Office  31
# 11  USER_0190  Transaction_0003  2019-01-01  Product_0970     Office  31
# ...

# %%
# 각 거래의 총 금액을 계산합니다. 총 금액 = (수량 * 평균금액) + 배송료
total_sales['총구매금액'] = (total_sales['수량'] * total_sales['평균금액']) + total_sales['배송료']

# 고객ID와 거래날짜를 기준으로 총 구매금액을 집계합니다.
grouped_total_sales = total_sales.groupby(['고객ID', '거래날짜'])['총구매금액'].sum().reset_index()

print(grouped_total_sales)
# Out:
#            고객ID        거래날짜     총구매금액
# 0     USER_0000  2019-09-15    180.99
# 1     USER_0001  2019-03-24  11649.52
# 2     USER_0001  2019-11-01     83.24
# 3     USER_0001  2019-11-02   2767.28
# 4     USER_0002  2019-06-22    879.03
# ...         ...         ...       ...
# 3203  USER_1465  2019-04-05    132.37
# 3204  USER_1465  2019-06-20     20.69
# 3205  USER_1466  2019-10-23    304.00
# 3206  USER_1467  2019-07-29   2354.11
# 3207  USER_1467  2019-10-10   4726.40
#
# [3208 rows x 3 columns]

# %%
grouped_total_sales.hist()
# Out:
# array([[<Axes: title={'center': '총구매금액'}>]], dtype=object)

# %%
grouped_total_sales.describe(include='all')
# Out:
#              고객ID        거래날짜         총구매금액
# count        3208        3208   3208.000000
# unique       1468         365           NaN
# top     USER_0118  2019-08-01           NaN
# freq           34          30           NaN
# mean          NaN         NaN   1629.498033
# std           NaN         NaN   2109.268989
# min           NaN         NaN      6.510000
# 25%           NaN         NaN    273.570000
# 50%           NaN         NaN    956.485000
# 75%           NaN         NaN   2206.600000
# max           NaN         NaN  26848.030000

# %%
# ttiti = df[(df['dayofweek']==6) & (df['price(원/kg)']==0)]

USER_1358 = total_sales[total_sales['고객ID']=='USER_1358']
USER_1358
# Out:
#            고객ID              거래ID        거래날짜          제품ID    제품카테고리  수량  \
# 0     USER_1358  Transaction_0000  2019-01-01  Product_0981  Nest-USA   1
# 1     USER_1358  Transaction_0001  2019-01-01  Product_0981  Nest-USA   1
# 2     USER_1358  Transaction_0002  2019-01-01  Product_0904    Office   1
# 3     USER_1358  Transaction_0003  2019-01-01  Product_0203   Apparel   5
# 4     USER_1358  Transaction_0003  2019-01-01  Product_0848      Bags   1
# ...         ...               ...         ...           ...       ...  ..
# 3349  USER_1358  Transaction_1758  2019-01-26  Product_1133   Bottles   1
# 3350  USER_1358  Transaction_1758  2019-01-26  Product_1134    Office   2
# 3351  USER_1358  Transaction_1758  2019-01-26  Product_1135  Headgear   1
# 3352  USER_1358  Transaction_1758  2019-01-26  Product_1143    Office   2
# 3353  USER_1358  Transaction_1758  2019-01-26  Product_1144    Office   1
#
#         평균금액  배송료      쿠폰상태 성별     고객지역  가입기간   총구매금액
# ...

# %%
USER_1359 = total_sales[total_sales['고객ID']=='USER_1359']
USER_1359
# Out:
#            고객ID              거래ID        거래날짜          제품ID     제품카테고리  수량  \
# 2099  USER_1359  Transaction_1110  2019-01-17  Product_0981   Nest-USA   1
# 2100  USER_1359  Transaction_1111  2019-01-17  Product_0976   Nest-USA   1
# 2101  USER_1359  Transaction_1112  2019-01-17  Product_0983   Nest-USA   1
# 2102  USER_1359  Transaction_1113  2019-01-17  Product_0976   Nest-USA   1
# 2103  USER_1359  Transaction_1113  2019-01-17  Product_0983   Nest-USA   1
# 2104  USER_1359  Transaction_1113  2019-01-17  Product_0984   Nest-USA   1
# 2105  USER_1359  Transaction_1114  2019-01-17  Product_0892  Drinkware   2
# 2106  USER_1359  Transaction_1115  2019-01-17  Product_0285    Apparel   1
# 2107  USER_1359  Transaction_1115  2019-01-17  Product_0493    Apparel   1
# 2108  USER_1359  Transaction_1115  2019-01-17  Product_0880  Drinkware   2
# 2109  USER_1359  Transaction_1116  2019-01-17  Product_0270    Apparel   1
# ...

# %%
USER_0118 = total_sales[total_sales['고객ID']=='USER_0118']
USER_0118
# Out:
#             고객ID               거래ID        거래날짜          제품ID    제품카테고리  수량  \
# 1015   USER_0118   Transaction_0536  2019-01-08  Product_0201   Apparel   3
# 2541   USER_0118   Transaction_1339  2019-01-20  Product_0981  Nest-USA   1
# 6158   USER_0118   Transaction_3192  2019-02-18  Product_0976  Nest-USA   2
# 6159   USER_0118   Transaction_3193  2019-02-18  Product_0976  Nest-USA   2
# 6160   USER_0118   Transaction_3194  2019-02-18  Product_0976  Nest-USA   1
# ...          ...                ...         ...           ...       ...  ..
# 36597  USER_0118  Transaction_16284  2019-09-05  Product_0984  Nest-USA   1
# 38121  USER_0118  Transaction_16900  2019-09-15  Product_0117   Apparel   1
# 38122  USER_0118  Transaction_16900  2019-09-15  Product_0286   Apparel   1
# 38123  USER_0118  Transaction_16900  2019-09-15  Product_0942    Office   1
# 38124  USER_0118  Transaction_16900  2019-09-15  Product_0945    Office   1
#
#          평균금액    배송료      쿠폰상태 성별     고객지역  가입기간   총구매금액
# ...

# %%
jan_1 = total_sales[total_sales['거래날짜']=='2019-01-01']
# jan_1_used_coupons = jan_1[jan_1['쿠폰상태'] == 'Used']
jan_1_used_coupons = jan_1[(jan_1['쿠폰상태'] == 'Used') | (jan_1['쿠폰상태'] == 'Clicked')]
jan_1_used_coupons.head()
jan_1_used_rev = jan_1_used_coupons['평균금액'].sum()
jan_1_used_rev
# Out:
# 4522.13

# %%
jan_2 = total_sales[total_sales['거래날짜']=='2019-01-02']
jan_2
# Out:
#           고객ID              거래ID        거래날짜          제품ID       제품카테고리  수량  \
# 89   USER_0585  Transaction_0041  2019-01-02  Product_0925     Headgear   2
# 90   USER_0585  Transaction_0042  2019-01-02  Product_0195    Lifestyle   2
# 91   USER_0585  Transaction_0043  2019-01-02  Product_0983     Nest-USA   1
# 92   USER_0585  Transaction_0044  2019-01-02  Product_0982  Nest-Canada   1
# 93   USER_0585  Transaction_0044  2019-01-02  Product_0987  Nest-Canada   3
# ..         ...               ...         ...           ...          ...  ..
# 199  USER_0025  Transaction_0108  2019-01-02  Product_0976     Nest-USA   2
# 200  USER_0025  Transaction_0109  2019-01-02  Product_0981     Nest-USA   2
# 201  USER_0025  Transaction_0110  2019-01-02  Product_0981     Nest-USA   1
# 202  USER_0025  Transaction_0110  2019-01-02  Product_0985     Nest-USA   3
# 203  USER_0025  Transaction_0111  2019-01-02  Product_0983     Nest-USA   1
#
#        평균금액  배송료      쿠폰상태 성별        고객지역  가입기간   총구매금액
# ...

# %%
# 각 거래에서의 총 금액을 계산합니다. 총 금액 = 수량 * 평균금액
total_sales['총금액'] = total_sales['수량'] * total_sales['평균금액']

# 제품 카테고리별로 총금액을 합산합니다.
category_sales = total_sales.groupby('제품카테고리')['총금액'].sum().reset_index()

category_sales
# Out:
#                   제품카테고리         총금액
# 0            Accessories     7295.88
# 1                Android      711.03
# 2                Apparel   591145.80
# 3              Backpacks     8772.69
# 4                   Bags   151314.43
# 5                Bottles     6923.65
# 6              Drinkware   200707.83
# 7                    Fun     6029.01
# 8             Gift Cards    19533.82
# 9                 Google     9420.47
# 10              Headgear    53471.44
# 11            Housewares     4637.32
# 12             Lifestyle    74385.70
# 13             More Bags     2946.96
# 14                  Nest   518193.50
# 15           Nest-Canada    70910.40
# 16              Nest-USA  2554202.39
# 17  Notebooks & Journals   107085.96
# 18                Office   276794.40
# 19                  Waze     6311.94

# %%
plt.figure(figsize=(10,6))

plt.bar(category_sales['제품카테고리'], category_sales['총금액'])
plt.title('제품 카테고리별 총금액')
plt.xlabel('제품 카테고리')
plt.ylabel('총금액')
plt.xticks(rotation=90)
plt.show()

# %%
total_sales
# Out:
#             고객ID               거래ID        거래날짜          제품ID    제품카테고리  수량  \
# 0      USER_1358   Transaction_0000  2019-01-01  Product_0981  Nest-USA   1
# 1      USER_1358   Transaction_0001  2019-01-01  Product_0981  Nest-USA   1
# 2      USER_1358   Transaction_0002  2019-01-01  Product_0904    Office   1
# 3      USER_1358   Transaction_0003  2019-01-01  Product_0203   Apparel   5
# 4      USER_1358   Transaction_0003  2019-01-01  Product_0848      Bags   1
# ...          ...                ...         ...           ...       ...  ..
# 52919  USER_0504  Transaction_25056  2019-12-31  Product_0976  Nest-USA   1
# 52920  USER_0504  Transaction_25057  2019-12-31  Product_0413   Apparel   1
# 52921  USER_0504  Transaction_25058  2019-12-31  Product_0989  Nest-USA   1
# 52922  USER_0562  Transaction_25059  2019-12-31  Product_0985  Nest-USA   5
# 52923  USER_0562  Transaction_25060  2019-12-31  Product_0984  Nest-USA   4
#
# ...

# %%
total_sales['거래날짜'] = pd.to_datetime(total_sales['거래날짜'])
total_sales['month'] = total_sales['거래날짜'].dt.month
total_sales['day'] = total_sales['거래날짜'].dt.day
total_sales['dayofweek'] = total_sales['거래날짜'].dt.dayofweek

# %%
total_sales
# Out:
#             고객ID               거래ID       거래날짜          제품ID    제품카테고리  수량  \
# 0      USER_1358   Transaction_0000 2019-01-01  Product_0981  Nest-USA   1
# 1      USER_1358   Transaction_0001 2019-01-01  Product_0981  Nest-USA   1
# 2      USER_1358   Transaction_0002 2019-01-01  Product_0904    Office   1
# 3      USER_1358   Transaction_0003 2019-01-01  Product_0203   Apparel   5
# 4      USER_1358   Transaction_0003 2019-01-01  Product_0848      Bags   1
# ...          ...                ...        ...           ...       ...  ..
# 52919  USER_0504  Transaction_25056 2019-12-31  Product_0976  Nest-USA   1
# 52920  USER_0504  Transaction_25057 2019-12-31  Product_0413   Apparel   1
# 52921  USER_0504  Transaction_25058 2019-12-31  Product_0989  Nest-USA   1
# 52922  USER_0562  Transaction_25059 2019-12-31  Product_0985  Nest-USA   5
# 52923  USER_0562  Transaction_25060 2019-12-31  Product_0984  Nest-USA   4
#
# ...

# %%
category_sales_days = total_sales.groupby(['거래날짜','제품카테고리'])['총금액'].sum().reset_index()
category_sales_days
# Out:
#            거래날짜     제품카테고리      총금액
# 0    2019-01-01    Apparel   712.19
# 1    2019-01-01       Bags   168.36
# 2    2019-01-01  Drinkware   684.79
# 3    2019-01-01        Fun    37.08
# 4    2019-01-01   Headgear   247.52
# ...         ...        ...      ...
# 3899 2019-12-31  Lifestyle     4.07
# 3900 2019-12-31       Nest  1822.51
# 3901 2019-12-31   Nest-USA  7904.62
# 3902 2019-12-31     Office    10.71
# 3903 2019-12-31       Waze    19.36
#
# [3904 rows x 3 columns]

# %%
category_sales_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3904 entries, 0 to 3903
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래날짜    3904 non-null   datetime64[ns]
#  1   제품카테고리  3904 non-null   object
#  2   총금액     3904 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 91.6+ KB

# %%
# datetime 형식 변환 

category_sales_days['거래날짜'] = pd.to_datetime(category_sales_days['거래날짜'])

# %%
import matplotlib.dates as mdates

plt.figure(figsize=(50,15))

sns.lineplot(data=category_sales_days, x='거래날짜', y='총금액', hue='제품카테고리')
plt.title('거래날짜별 제품 카테고리 매출액 추이')

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.show()

# %%
sales_dayofweek = total_sales.groupby('dayofweek')['총금액'].sum()
sales_dayofweek
# Out:
# dayofweek
# 0    365626.90
# 1    396819.65
# 2    826622.00
# 3    840433.85
# 4    872004.86
# 5    673068.03
# 6    696219.33
# Name: 총금액, dtype: float64

# %%
plt.figure(figsize=(8,5))

sales_dayofweek.plot(kind='bar')
plt.title('요일별 총 매출액')
plt.xlabel('요일')
plt.show()

# 0: 월요일 5: 토요일, 6:일요일

# %% [markdown]
# - 피벗

# %%
pivot_discount = discount.pivot_table(index='월', columns='제품카테고리', values='할인율')
# pivot_discount = pivot_discount.sort_index()  # 월별 sorting 안되네요 ㅠ
pivot_discount
# Out:
# 제품카테고리  Accessories  Android  Apparel  Bags  Bottles  Drinkware  Gift Cards  \
# 월
# Apr            10.0     10.0     10.0  10.0     10.0       10.0        10.0
# Aug            20.0     20.0     20.0  20.0     20.0       20.0        20.0
# Dec            30.0     30.0     30.0  30.0     30.0       30.0        30.0
# Feb            20.0     20.0     20.0  20.0     20.0       20.0        20.0
# Jan            10.0     10.0     10.0  10.0     10.0       10.0        10.0
# Jul            10.0     10.0     10.0  10.0     10.0       10.0        10.0
# Jun            30.0     30.0     30.0  30.0     30.0       30.0        30.0
# Mar            30.0     30.0     30.0  30.0     30.0       30.0        30.0
# May            20.0     20.0     20.0  20.0     20.0       20.0        20.0
# Nov            20.0     20.0     20.0  20.0     20.0       20.0        20.0
# Oct            10.0     10.0     10.0  10.0     10.0       10.0        10.0
# ...

# %%
month_revenue = total_sales.groupby('month')['총금액'].sum()
month_revenue
# Out:
# month
# 1     403624.58
# 2     310819.80
# 3     349608.09
# 4     401618.42
# 5     307763.42
# 6     321081.38
# 7     372638.07
# 8     401210.37
# 9     360548.40
# 10    409681.28
# 11    508942.62
# 12    523258.19
# Name: 총금액, dtype: float64

# %%
marketing
# Out:
#              날짜  오프라인비용    온라인비용
# 0    2019-01-01    4500  2424.50
# 1    2019-01-02    4500  3480.36
# 2    2019-01-03    4500  1576.38
# 3    2019-01-04    4500  2928.55
# 4    2019-01-05    4500  4055.30
# ..          ...     ...      ...
# 360  2019-12-27    4000  3396.87
# 361  2019-12-28    4000  3246.84
# 362  2019-12-29    4000  2546.58
# 363  2019-12-30    4000   674.31
# 364  2019-12-31    4000  2058.75
#
# [365 rows x 3 columns]

# %%
marketing['날짜'] = pd.to_datetime(marketing['날짜'])

marketing['month'] = marketing['날짜'].dt.month
marketing['day'] = marketing['날짜'].dt.day
marketing['dayofweek'] = marketing['날짜'].dt.dayofweek 
marketing
# Out:
#             날짜  오프라인비용    온라인비용  month  day  dayofweek
# 0   2019-01-01    4500  2424.50      1    1          1
# 1   2019-01-02    4500  3480.36      1    2          2
# 2   2019-01-03    4500  1576.38      1    3          3
# 3   2019-01-04    4500  2928.55      1    4          4
# 4   2019-01-05    4500  4055.30      1    5          5
# ..         ...     ...      ...    ...  ...        ...
# 360 2019-12-27    4000  3396.87     12   27          4
# 361 2019-12-28    4000  3246.84     12   28          5
# 362 2019-12-29    4000  2546.58     12   29          6
# 363 2019-12-30    4000   674.31     12   30          0
# 364 2019-12-31    4000  2058.75     12   31          1
#
# [365 rows x 6 columns]

# %%
marketing_monthly_revenue = marketing.groupby('month')[['오프라인비용','온라인비용']].sum()
marketing_monthly_revenue
# Out:
#        오프라인비용     온라인비용
# month
# 1       96600  58328.95
# 2       81300  55807.92
# 3       73500  48750.09
# 4       96000  61026.83
# 5       65500  52759.64
# 6       80500  53818.14
# 7       67500  52717.85
# 8       85500  57404.15
# 9       83000  52514.54
# 10      93500  57724.65
# 11      93000  68144.96
# 12     122000  76648.75

# %%
marketing_monthly_revenue['온오프라인비용'] = marketing_monthly_revenue['오프라인비용'] + marketing_monthly_revenue['온라인비용']
marketing_monthly_revenue
# Out:
#        오프라인비용     온라인비용    온오프라인비용
# month
# 1       96600  58328.95  154928.95
# 2       81300  55807.92  137107.92
# 3       73500  48750.09  122250.09
# 4       96000  61026.83  157026.83
# 5       65500  52759.64  118259.64
# 6       80500  53818.14  134318.14
# 7       67500  52717.85  120217.85
# 8       85500  57404.15  142904.15
# 9       83000  52514.54  135514.54
# 10      93500  57724.65  151224.65
# 11      93000  68144.96  161144.96
# 12     122000  76648.75  198648.75

# %%
marketing_profit = month_revenue / marketing_monthly_revenue['온오프라인비용']
marketing_profit
# Out:
# month
# 1     2.605224
# 2     2.266972
# 3     2.859778
# 4     2.557642
# 5     2.602438
# 6     2.390454
# 7     3.099690
# 8     2.807549
# 9     2.660588
# 10    2.709091
# 11    3.158291
# 12    2.634088
# dtype: float64
